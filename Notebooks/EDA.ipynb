# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### **Import Dataset**

# %%
df = pd.read_csv("C:\\Users\\Neeta Devke\\bank.csv")
df
# Out:
#        age          job  marital  education default  balance housing loan
# 0       59       admin.  married  secondary      no     2343     yes   no  \
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome
# ...

# %% [markdown]
# *Check the First Five Records of the Dataset*

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown  \
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %% [markdown]
# *Check the Last Five Records of the Dataset*

# %%
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan
# 11157   33  blue-collar   single    primary      no        1     yes   no  \
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome
# 11157  cellular   20   apr       257         1     -1         0  unknown  \
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %% [markdown]
# *Check the Sample Five Records of Dataset*

# %%
df.sample(5)
# Out:
#        age         job  marital  education default  balance housing loan
# 10227   58  management  married  secondary      no     -382      no   no  \
# 7805    30    services   single  secondary      no     1510     yes   no
# 8502    29      admin.   single  secondary      no     1992      no   no
# 10763   55    services  married   tertiary      no      606      no  yes
# 10420   33  technician  married  secondary      no        8      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 10227  telephone    5   feb       398         4    189        12  success  \
# 7805    cellular   18   nov       191         1     -1         0  unknown
# 8502    cellular   12   apr       119         2     -1         0  unknown
# 10763   cellular   18   nov       114         2     -1         0  unknown
# 10420   cellular   29   aug       462         2     -1         0  unknown
#
#       deposit
# 10227      no
# 7805       no
# 8502       no
# 10763      no
# ...

# %% [markdown]
# *Check Basic information of the Dataset*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# *Check the Dataset of Columns*

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# *Check the Mathematic Relationship of the Dataset*

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000  \
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# *Check the Null Values of Dataset*

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# *Check the Categorical Columns of Dataset*

# %%
cat_columns = df.columns[df.dtypes == 'object']

# %%
cat_columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# *Check the Numerical Columns of the Dataset*

# %%
num_columns = df.columns[df.dtypes != 'object']
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %% [markdown]
# ### **Univariant Analysis**
#
# - Categorical Columns: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'deposit']
#
# - Numerical Columns: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# ### **Plot on Categorical Columns**

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Bar plot of Categorical Columns")
for i in enumerate(df[cat_columns]):
    plt.subplot(4,3, i[0]+1)
    df[i[1]].value_counts().plot(kind='bar')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Pie Plots of Categorical Columns", size = 22, fontweight = 'bold')

for i in enumerate(df[cat_columns]):
    plt.subplot(4,3, i[0]+1)
    df[i[1]].value_counts().plot.pie(ylabel="", autopct="%.1f%%", startangle=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Countplot of Categorical Columns")
for i in enumerate(df[cat_columns]):
    plt.subplot(4,3, i[0]+1)
    ax = sns.countplot(x = i[1], data = df)
    plt.bar_label(ax.containers[0])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Countplot", size=22, fontweight='bold')
for i in enumerate(df[cat_columns]):
    plt.subplot(4,3, i[0]+1)
    ax = sns.countplot(x = i[1], hue='deposit', data = df)
    plt.bar_label(ax.containers[0])
    plt.bar_label(ax.containers[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Bivariant Analysis**

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Barplot of Numerical Columns", size = 22, fontweight = 'bold')

for i in enumerate(df[num_columns]):
    plt.subplot(4, 2, i[0]+1)
    sns.barplot(y=i[1], x = 'deposit', data=df)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Boxplot of Numerical Columns", size = 22, fontweight = 'bold')

for i in enumerate(df[num_columns]):
    plt.subplot(4, 2, i[0]+1)
    sns.boxplot(y=i[1], x = 'deposit', data=df)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle("Violinplot of Numerical Columns", size = 22, fontweight='bold')
for i in enumerate(df[num_columns]):
    plt.subplot(4,2, i[0]+1)
    sns.violinplot(y = i[1], x='deposit', data=df)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Scatterplot of Numerical Columns", size=22, fontweight='bold')
for i in enumerate(df[num_columns]):
    plt.subplot(4, 2, i[0]+1)
    sns.scatterplot(x= 'deposit', y = i[1], data = df)
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Stripplot of Numerical Columns", size=22, fontweight='bold')
for i in enumerate(df[num_columns]):
    plt.subplot(4, 2, i[0]+1)
    sns.stripplot(x= 'deposit', y = i[1], data = df)
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Scatterplot of Numerical Columns", size=22, fontweight='bold')
for i in enumerate(df[cat_columns]):
    plt.subplot(4, 3, i[0]+1)
    sns.scatterplot(y= 'deposit', x = i[1], data = df)
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Histplot of Categorical Columns", size=22, fontweight='bold')
for i in enumerate(df[cat_columns]):
    plt.subplot(4, 3, i[0]+1)
    sns.histplot(df[i[1]])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.suptitle("Distplot of Numerical Columns", size=22, fontweight='bold')
for i in enumerate(df[num_columns]):
    plt.subplot(4, 2, i[0]+1)
    sns.distplot(df[i[1]])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_6752\3199478617.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i[1]])
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_6752\3199478617.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i[1]])
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# ### **Correlation Matrix**

# %%
sns.heatmap(round(df[num_columns].corr(),2), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# **Calculated correlation between two variables (r)**
#
# - gets a value between -1 and 1.
# - No correlaiton r=0
# - Very weak correlation: r<20
# - Weak correlation: between 0.20-0.49
# - Moderate correlation: between 0.5-0.79
# - Strong correlation: between 0.8-0.99
# - Perfect correlation: r=1
# - Looking at it, there is a moderate correlation between the days
# and the previous ones. (r=0.51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# ### **Outlier Detection**

# %%
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
from collections import Counter
def detect_outliers(df, features):
    outlier_indices = []
    for col in features:
        
        # First Quartile 
        Q1 = np.percentile(df[col], 25)
        
        # Third Quartile
        Q3 = np.percentile(df[col], 75)
        
        # IQR
        IQR = Q3 - Q1
        
        # Outlier Step
        Outlier_step = IQR * 1.5
        
        # Detect Outlier and their indices
        outlier_list_col = df[(df[col] < Q1 - Outlier_step) | (df[col]) > Q3 - Outlier_step]
        
        # store indices
        outlier_indices.extend(outlier_list_col)
        
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items())
    
    return multiple_outliers

# %%
df.loc[detect_outliers(df, ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.loc[detect_outliers(df, ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'])]
#
# File d:\Bank_Marketing_Analysis\venv\lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\Bank_Marketing_Analysis\venv\lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# ...
